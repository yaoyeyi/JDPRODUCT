# %%
import requests 
import time
import random
import re
import json
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jieba as jb
import jieba.analyse

# %% [markdown]
# # 将爬虫伪装成浏览器 反扒

# %%
#User-Agents列表
User_Agents = ["Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",            
               "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)",
               "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)",
               "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)",              
               "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)",
               "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)",
               "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6",
               "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1",
               "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0"]

# 随机生成user-agent
User_Agent=random.choice(User_Agents)
#User_Agent

# %%
#设置请求中头文件的信息
headers = {'User-Agent':User_Agent,
'Accept':'text/html;q=0.9,*/*;q=0.8',
'Accept-Charset':'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
'Connection':'close',
'Referer':'https://www.jd.com/'
}

# %%
#代理ip

# %% [markdown]
# 由于京东销售版本繁多 如华北专享 电信赠费，而且评论少，故此次只抓取公开版相关评论
# 抓取skuID

# %%
#skuId列表获取
#商品初始地址
url_start = "https://item.jd.com/5089253.html"
reponse=requests.get(url=url_start,headers=headers)
data = reponse.text
reg = re.compile(r'"skuId":(.*?),')
skuId_list = reg.findall(data)
skuId_list
# Out:
# ['5089235',
#  '5089239',
#  '5089237',
#  '5089253',
#  '5965065',
#  '5998902',
#  '5965087',
#  '5998886',
#  '5729526',
#  '5729542',
#  '5729544',
#  '5563195',
#  '6435172',
#  '6621707',
#  '6435196',
#  '6435194',
#  '6351212',
#  '6493539',
#  '6493555',
#  '6493553',
#  '6493541',
#  '6351222',
#  '6351214',
#  '6493485']

# %% [markdown]
# 根据skuID拼接评论地址

# %%
#获取所有评论链接
url_comment_list = []
url_comment_format = "https://sclub.jd.com/comment/skuProductPageComments.action?productId={}&score={}&sortType=6&pageSize=10&page={}"
for skuId in skuId_list:
    #获取maxpage
    for score in range(1,6):
        url_comment_p0 = url_comment_format.format(skuId,score,0)
        response_p0 = requests.get(url=url_comment_p0,headers=headers)
        json_p0 = json.loads(response_p0.text) 
        maxpage= json_p0.get('maxPage')
        page_num_list=random.sample(range(maxpage), maxpage)
        print(skuId,score,maxpage)
        for page_num in page_num_list:
            url_comment =url_comment_format.format(skuId,score,page_num)
            url_comment_list.append(url_comment)
len(url_comment_list)
# Out:
# 5089235 1 30
# 5089235 2 20
# 5089235 3 100
# 5089235 4 100
# 5089235 5 40
# 5089239 1 30
# 5089239 2 10
# 5089239 3 100
# 5089239 4 100
# 5089239 5 30
# 5089237 1 10
# 5089237 2 10
# 5089237 3 100
# 5089237 4 100
# 5089237 5 20
# 5089253 1 50
# 5089253 2 30
# 5089253 3 100
# 5089253 4 100
# 5089253 5 60
# 5965065 1 0
# 5965065 2 0
# 5965065 3 0
# 5965065 4 0
# 5965065 5 0
# 5998902 1 0
# 5998902 2 0
# 5998902 3 0
# 5998902 4 0
# 5998902 5 0
# 5965087 1 0
# 5965087 2 0
# 5965087 3 0
# 5965087 4 0
# 5965087 5 0
# 5998886 1 0
# 5998886 2 0
# 5998886 3 0
# 5998886 4 0
# 5998886 5 0
# 5729526 1 0
# 5729526 2 0
# 5729526 3 0
# 5729526 4 0
# 5729526 5 0
# 5729542 1 0
# 5729542 2 0
# 5729542 3 0
# 5729542 4 0
# 5729542 5 0
# 5729544 1 0
# 5729544 2 0
# 5729544 3 0
# 5729544 4 0
# 5729544 5 0
# 5563195 1 0
# 5563195 2 0
# 5563195 3 0
# 5563195 4 0
# 5563195 5 0
# 6435172 1 0
# 6435172 2 0
# 6435172 3 0
# 6435172 4 0
# 6435172 5 0
# 6621707 1 0
# 6621707 2 0
# 6621707 3 0
# 6621707 4 0
# ...

# %%
#单个商品单个评论页数据提取，存储函数
def getcomment(comment_js,tablename): 
    #将多余的部分删掉使它成为json格式  
    #reg = re.compile(r'fetchJSON_comment98vv32580\(')         
    #data = reg.sub('',comment_js)  
    #reg1 = re.compile(r"\)\;")  
    #data = reg1.sub(' ',data)
    # 格式转换     
    json_ = json.loads(comment_js) 
    #信息提取
    df = pd.DataFrame()
    drop_columns = ["afterUserComment","images","showOrderComment","referenceImage","videos","productSales","guid","referenceName",
               "userImage","userLevelColor","userImageUrl","userImgFlag","afterImages","afterVideos"]
    #遍历js中用户评论
    for item in json_['comments']:
        df_item = pd.DataFrame.from_dict(item, orient='index').transpose()
        #数据库无法存储字典元素，故删除afterUserComment并保留有效数据
        if item.get('afterUserComment'):
            df_item['addcreated'] = item['afterUserComment']['created']
            df_item['addcontent'] = item['afterUserComment']['hAfterUserComment']['content']
        if item.get('commentTags'):
            df_item = df_item.drop('commentTags',axis=1)
        df_item['storage'] = item['productSales'][0]["saleValue"]
        df =df.append(df_item)
    #无用信息
    for uselesskey in drop_columns:
        if uselesskey in df.columns:
            df= df.drop(uselesskey,axis=1)
        else:
            pass
    #return df_drop
    #打开数据库存储数据
    engine = create_engine('postgresql://postgres:947172@localhost:5432/postgres') 
    #create_engine说明：dialect[+driver]://user:password@host/dbname[?key=value..]
    try:
        df.to_sql(tablename,engine,index=False,if_exists='append')
        #conn = psycopg2.connect(database="platoon", user="postgres", password="postgres", 
                           # host="192.168.10.80",port="5432")
        #数据库游标
        #cur=conn.cursor()  
        print ('数据存储成功' )  
    except Exception as e:
        print(e)
        url_comment_fail.append(url_comment)
#getcomment(c).transpose()

# %%
url_comment_list = url_comment_fail

# %%
#商品评论内容解析并存储
getpages = 1
url_comment_fail = []

for url_comment in url_comment_list:
    #异常处理
    try:
        response = requests.get(url=url_comment,headers=headers,timeout = 5)
        comment_js = response.text
        print("当前抓取商品{},已抓取{}页共{}页，状态:{}\n页面:\n{}".format(skuId,getpages,len(url_comment_list),response,url_comment))
        getpages = getpages+1
    except:
        print(response)
        #获取失败链接加入链接列表
        url_comment_fail.append(url_comment)
    #随机休息
    time.sleep(random.randint(2,5))
    getpages = getpages+1
    getcomment(comment_js,"0408")
# Out:
# 当前抓取商品6493485,已抓取1页共59页，状态:<Response [200]>
# 页面:
# https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=23
# 数据存储成功
# 当前抓取商品6493485,已抓取3页共59页，状态:<Response [200]>
# 页面:
# https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=18
# 数据存储成功
# 当前抓取商品6493485,已抓取5页共59页，状态:<Response [200]>
# 页面:
# https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=21
# 数据存储成功
# 当前抓取商品6493485,已抓取7页共59页，状态:<Response [200]>
# 页面:
# https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=2&sortType=6&pageSize=10&page=15
# 数据存储成功
# 当前抓取商品6493485,已抓取9页共59页，状态:<Response [200]>
# 页面:
# https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=2&sortType=6&pageSize=10&page=14
# 数据存储成功
# 当前抓取商品6493485,已抓取11页共59页，状态:<Response [200]>
# 页面:
# ...

# %%
url_comment = "https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=23"
response = requests.get(url=url_comment,headers=headers,timeout = 5)
comment_js = response.text
# 格式转换     
json_ = json.loads(comment_js) 
#信息提取
df = pd.DataFrame()
drop_columns = ["afterUserComment","images","showOrderComment","referenceImage","videos","productSales","guid","referenceName",
           "userImage","userLevelColor","userImageUrl","userImgFlag","afterImages","afterVideos"]
#遍历js中用户评论
for item in json_['comments']:
    df_item = pd.DataFrame.from_dict(item, orient='index').transpose()
    #数据库无法存储字典元素，故删除afterUserComment并保留有效数据
    if item.get('afterUserComment'):
        df_item['addcreated'] = item['afterUserComment']['created']
        df_item['addcontent'] = item['afterUserComment']['hAfterUserComment']['content']
    if item.get('commentTags'):
        df_item = df_item.drop('commentTags')
    df =df.append(df_item)
#无用信息
for uselesskey in drop_columns:
    if uselesskey in df.columns:
        df= df.drop(uselesskey,axis=1)
    else:
        pass

# %%
df.transpose()
[{"id":6920339,"name":"黑科技","pin":"","status":0,"rid":31385,"productId":5089235,"commentId":11079814396,"created":"2017-12-17 10:21:46","modified":"2017-12-17 10:21:46"}]
# Out:
#                                                                   0  \
# addcontent                                                      NaN
# addcreated                                                      NaN
# afterDays                                                         0
# anonymousFlag                                                     1
# commentTags                                                     NaN
# content           不知道为什么边缘有几道划痕 刚开始以为是灰尘呢 不仔细看都看不出来 像撞在了哪里或者被什么东西划了
# creationTime                                    2017-12-17 17:48:22
# days                                                              5
# discussionId                                                    NaN
# firstCategory                                                  9987
# id                                                      11081170453
# imageCount                                                      NaN
# integral                                                        -20
# ...

# %%
a = {"b":3}
b = {"d":a["b"]}

# %%
a = pd.DataFrame()
try:
    b = pd.DataFrame({"s":np.random.randn(10)})
    r = requests.get(url_comment,headers=headers,timeout = 0.05)
    print("2")
except:
    print(r)
    a = a.append(b)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                     # otherwise it looks like a programming error was the cause.
# --> 386                     six.raise_from(e, None)
#     387         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#
# ...

# %%
url_comment_fail
# Out:
# ['https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=23',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=18',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=1&sortType=6&pageSize=10&page=21',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=2&sortType=6&pageSize=10&page=15',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=2&sortType=6&pageSize=10&page=14',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=2&sortType=6&pageSize=10&page=12',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=5&sortType=6&pageSize=10&page=35',
#  'https://sclub.jd.com/comment/skuProductPageComments.action?productId=5089235&score=5&sortType=6&pageSize=10&page=24',
# ...

# %%
def s():
    b.remove(2)
def a():
    b= 3

# %%
b=[2,2,2,3,4,3]

b.remove(2)
b
# Out:
# [2, 2, 3, 4, 3]

# %%
#链接获取评论js
def getcommentjs(url_commentjs):

# %%
#评论地址构造函数

# %%
#商品地址列表

# %%
#设置URL的第一部分
url1='https://sclub.jd.com/comment/productPageComments.action?productId=10001234327&amp;amp;amp;score=0&amp;amp;amp;sortType=3&amp;amp;amp;page='
#设置URL的第二部分
url2='&amp;amp;amp;pageSize=10&amp;amp;amp;callback=fetchJSON_comment98vv41127'
#乱序输出0-80的唯一随机数
ran_num=random.sample(range(5), 5)
ran_num
# Out:
# [1, 3, 0, 4, 2]

# %%
#拼接URL并乱序循环抓取页面
for i in ran_num:
    a = ran_num[0]
    if i == a:
        i=str(i)
        url=(url1+i+url2)
        r=requests.get(url=url,headers=headers)
        html=r.content
    else:
        i=str(i)
        url=(url1+i+url2)
        r=requests.get(url=url,headers=headers)
        html2=r.content
        html = html + html2
    time.sleep(5)
    print("当前抓取页面:",url,"状态:",r)
# Out:
# 当前抓取页面: https://sclub.jd.com/comment/productPageComments.action?productId=10001234327&amp;amp;amp;score=0&amp;amp;amp;sortType=3&amp;amp;amp;page=1&amp;amp;amp;pageSize=10&amp;amp;amp;callback=fetchJSON_comment98vv41127 状态: <Response [200]>
# 当前抓取页面: https://sclub.jd.com/comment/productPageComments.action?productId=10001234327&amp;amp;amp;score=0&amp;amp;amp;sortType=3&amp;amp;amp;page=3&amp;amp;amp;pageSize=10&amp;amp;amp;callback=fetchJSON_comment98vv41127 状态: <Response [200]>
# 当前抓取页面: https://sclub.jd.com/comment/productPageComments.action?productId=10001234327&amp;amp;amp;score=0&amp;amp;amp;sortType=3&amp;amp;amp;page=0&amp;amp;amp;pageSize=10&amp;amp;amp;callback=fetchJSON_comment98vv41127 状态: <Response [200]>
# 当前抓取页面: https://sclub.jd.com/comment/productPageComments.action?productId=10001234327&amp;amp;amp;score=0&amp;amp;amp;sortType=3&amp;amp;amp;page=4&amp;amp;amp;pageSize=10&amp;amp;amp;callback=fetchJSON_comment98vv41127 状态: <Response [200]>
# ...

# %%
#对抓取的页面进行编码
html=str(html)

# %%
import os
homedir = os.getcwd()
homedir
# Out:
# 'C:\\Users\\Weizh\\Jupyter\\JDPRODUCT'

# %%
#将编码后的页面输出为txt文本存储
file = open("./data/page.txt", "w")
file.write(html)
file.close()

# %%
#删除重复次数过多链接
def remove_fail_url(url_list,n = 5):
    dic_num = {i:url_list.count(i) for i in set(url_list)}
    for i in [k for k,v in dic_num.items() if v > n]:
        if i in url_list:
            return i

# %%
#读取存储的txt文本文件
html = open("./data/page.txt", 'r').read()

# %%
#评论解析
#提取评论页数maxpage
"maxPage": 100,
maxpage = re.findall(r'"maxPage": (.*)',c)
#使用正则提取userClient字段信息
userClient=re.findall(r',"usefulVoteCount".*?,"userClientShow":(.*?),',html)
#使用正则提取userLevel字段信息
userLevel=re.findall(r'"referenceImage".*?,"userLevelName":(.*?),',html)
#使用正则提取productColor字段信息
productColor=re.findall(r'"creationTime".*?,"productColor":(.*?),',html)
#使用正则提取recommend字段信息
recommend=re.findall(r'"creationTime".*?,"recommend":(.*?),',html)
#使用正则提取nickname字段信息
nickname=re.findall(r'"creationTime".*?,"nickname":(.*?),',html)
#使用正则提取userProvince字段信息
userProvince=re.findall(r'"referenceImage".*?,"userProvince":(.*?),',html)
#使用正则提取usefulVoteCount字段信息
usefulVoteCount=re.findall(r'"referenceImage".*?,"usefulVoteCount":(.*?),',html)
#使用正则提取days字段信息
days=re.findall(r'"usefulVoteCount".*?,"days":(.*?)}',html)
#使用正则提取score字段信息
score=re.findall(r'"referenceImage".*?,"score":(.*?),',html)</pre>

# %%
#提取商品颜色productColor
productColor = re.findall(r'"productColor":"(.*?)"',c)
#提取商品版本productSize
productSize = re.findall(r'"productSize":"(.*?)"',c)
#提取用户等级userLevelName
userLevelName = re.findall(r'"userLevelName":"(.*?)"',c)
#提取用户等级id userLevelId
userLevelId = re.findall(r'"userLevelId":"(.*?)"',c)
#提取用户等京享值userExpValue
userExpValue = re.findall(r'"userExpValue":(.*?),',c)
#提取商品等级saleValue
saleValue = re.findall(r'"saleValue":"(.*?)GB"',c)
saleValue
#提取下单时间referenceTime
referenceTime = re.findall(r'"referenceTime":"(.*?)"',c)
referenceTime
#打分
score=re.findall(r'"productSales".*?,"score":(.*?),',c)
score
# Out:
# ['5', '5', '5', '5', '5', '5', '5', '5', '5']

# %%
#提取评论内容content,评论时间creationTime,是否置顶isTop,商品id referenceId,设备userClientShow，是否手机isMobile
columns_name = ["content","creationTime","isTop","referenceId","userClientShow","isMobile"]
content = re.findall(r'"showOrderComment".*?"content":"(.*?)","creationTime":"(.*?)","isTop":(\w*).*?"referenceId":"(\d*)".*?"userClientShow":"(.*?)".*?"isMobile":(\w*).*?',c)
content
#pd.DataFrame(content,columns=columns_name )
# Out:
# [('外壳是京东的二次封装，但不影响手机，没有磕碰，物流很快，拿到手上到处都是指纹，简直是指纹收集器， 整体次我的6sp小很多，忽然有些嫌小呢，总是隔代用体验一直都挺好的，开机更新了系统感觉很棒很惊艳。第一天抢购了五六次，每次都很失望，完全抢不到，会员的提前几分钟完全是噱头，这个在众多评论里也看到了，这次购买也就是随便一点，之前抢不到就忽然不想买了，这次意外之喜',
#   '2017-11-18 17:10:55',
#   'false',
#   '5089235',
#   '来自京东iPhone客户端',
#   'true'),
#  ('1:一直都说苹果系统很好，手机很好用，就是一直觉得贵，没买，同事的苹果5s拿过来看，现在都还可以用，也是觉了，京东也一直没抢到，抢了个最贵的，2:这京东的包装也太简单了吧，一个袋子，就一个袋子。好歹也是上万的贵重物品，无力吐槽。3:拿到手沉垫垫的厚重感，oled屏幕很惊艳，屏幕大手机小，拿起来很爽，4:很多人都说烧屏幕，看看后续使用。5:王者也几乎适配了，不知道大家用的什么版本系统，现在11.1.1，最高也是11.1.2，一向有个不想升系统的习惯?，5:建议一定要戴套，不然满是指纹，钢化膜也必须滴。6:人生第一部苹果手机，期待完美体验！',
#   '2017-11-27 20:37:39',
#   'false',
#   '5089239',
#   '来自京东Android客户端',
#   'true'),
#  ('我很少给评论的，但是苹果x的评论必须写，我是一个科技爱好者，这款产品我用了几天以后，感觉面部识别的速度有待提升，而且面部识别貌似只能识别一次，就是说识别一次没通过，需要上滑解释健在识别一次，或锁屏在次扫描，没有指纹那么灵活，希望苹果后期软件更新能改掉这一点，反应速度也是非常的惊人，操作手势虽然有点复杂，但是用习惯了还是很方便的，功能方面都差不多吧，总体来说值得购买的，恐怕你用惯全面屏以后就再也不会用四方四正的屏了，在用几天追加评价，告诉你们到底值不值得买',
#   '2017-12-14 14:49:08',
#   'false',
#   '5089235',
#   '来自京东iPhone客户端',
#   'true'),
# ...
